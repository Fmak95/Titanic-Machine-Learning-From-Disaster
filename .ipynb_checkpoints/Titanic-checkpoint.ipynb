# %% [markdown]
# In this notebook we will be working on the famous binary classification problem using the titanic dataset. The goal is to correctly classify those that survived the titanic.

# %%
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# # Exploratory Data Analysis

# %%
#Read in the training data
train = pd.read_csv("./Data/train.csv")
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# **List of features with missing values:**
# - Age
# - Cabin
# - Embarked
#
# If we want to use these features in our model, we need to find a way to handle the missing data first.

# %% [markdown]
# ## Categorical Data Analysis:
#
# So for categorical data, let us see the correlation they have with the 'Survived' feature by grouping the categories and calculating the mean.
#
# **List of Categorical Features:**
# - Pclass
# - Embarked
# - Sex
# - SibSp
# - Parch

# %%
train[['Pclass','Survived']].groupby('Pclass').mean()
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
train[['Parch','Survived']].groupby('Parch').mean()
# Out:
#        Survived
# Parch
# 0      0.343658
# 1      0.550847
# 2      0.500000
# 3      0.600000
# 4      0.000000
# 5      0.200000
# 6      0.000000

# %%
train[['Sex','Survived']].groupby('Sex').mean()
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %%
train[['SibSp','Survived']].groupby('SibSp').mean()
# Out:
#        Survived
# SibSp
# 0      0.345395
# 1      0.535885
# 2      0.464286
# 3      0.250000
# 4      0.166667
# 5      0.000000
# 8      0.000000

# %%
train[['Embarked','Survived']].groupby('Embarked').mean()
# Out:
#           Survived
# Embarked
# C         0.553571
# Q         0.389610
# S         0.336957

# %% [markdown]
# **Trends that we can observe:**
# - Females had a much higher survival rate than males
# - First class people had higher survival rate (Pclass = 1)
# - Those that embarked in Cherbourg had higher survival rate (Embarked = C)

# %% [markdown]
# # Numerical Data Analysis:
#
# Now lets take a look at our numerical data. We will be using histograms to visualize the relationships between our numerical data and our target feature, 'Survived'.
#
# **List of Numerical Features:**
# - Age
# - Fare

# %%
#Left plot is histogram of people who did not survive
#Right plot is histogram of people who did survive
fig, ax = plt.subplots(1, 2, sharex='col', sharey='row', figsize=(20, 5))
train.loc[train['Survived'] == 0, ['Age']].hist(ax=ax[0])
train.loc[train['Survived'] == 1, ['Age']].hist(ax=ax[1])
plt.show()

# %%
#Left plot is histogram of people who did not survive
#Right plot is histogram of people who did survive
fig, ax = plt.subplots(1, 2, sharex='col', sharey='row', figsize=(20, 5))
train.loc[train['Survived'] == 0, ['Fare']].hist(ax=ax[0])
train.loc[train['Survived'] == 1, ['Fare']].hist(ax=ax[1])
plt.show()

# %% [markdown]
# **Trends that we observe:**
# - More children survived than those that died (Ages 0 - 10)
# - Most of the people who purchased a cheap ticket died.

# %% [markdown]
# # Handling Missing Data

# %%
from sklearn.impute import SimpleImputer

#Fill in Missing Data in Embarked Feature
imp = SimpleImputer(strategy="most_frequent")
embarked_imputed = imp.fit_transform(train['Embarked'].values.reshape(-1,1))
train['Embarked'] = embarked_imputed.reshape(-1)

#Fill in Missing Data in Age Feature
imp = SimpleImputer(strategy='median')
age_imputed = imp.fit_transform(train['Age'].values.reshape(-1,1))
train['Age'] = age_imputed.reshape(-1)

train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            891 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       891 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# # One Hot Encode the Text Categorical Features

# %%
from sklearn.preprocessing import LabelBinarizer

#Encode the 'Sex' Feature (1 = male, 0 = female)
encoder = LabelBinarizer()
sex_encoded = encoder.fit_transform(train['Sex'].values.reshape(-1,1))
train['Sex'] = sex_encoded

# %%
from sklearn.preprocessing import OneHotEncoder

#One Hot Encode the 'Embarked' Category ([0, 0, 1] = S, [1, 0, 0] = C, [0, 1, 0] = Q)
encoder = OneHotEncoder()
embarked_encoded = encoder.fit_transform(train['Embarked'].values.reshape(-1,1))
train['Embarked_S'] = embarked_encoded.toarray()[:,2]
train['Embarked_C'] = embarked_encoded.toarray()[:,0]
train['Embarked_Q'] = embarked_encoded.toarray()[:,1]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null int64
# Age            891 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       891 non-null object
# Embarked_S     891 non-null float64
# Embarked_C     891 non-null float64
# Embarked_Q     891 non-null float64
# dtypes: float64(5), int64(6), object(4)
# memory usage: 104.5+ KB

# %% [markdown]
# # Baseline Model (No Feature Engineering)
#
# So, before we do any feature engineering let us train some classifiers on the base features to see how well we perform.

# %%
features = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked_S', 'Embarked_C', 'Embarked_Q']

# %%
#Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier

tree_clf = DecisionTreeClassifier()
tree_clf.fit(train[features],train['Survived'])
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(tree_clf, train[features], train['Survived'], cv=5, scoring='accuracy')
print('Scores = {}'.format(scores))
print('Mean = {}'.format(scores.mean()))
print('Std = {}'.format(scores.std()))
# Out:
# Scores = [0.77094972 0.79888268 0.80898876 0.73595506 0.8079096 ]
# Mean = 0.784537165395826
# Std = 0.027909802619458336

# %%
#Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier

forest_clf = RandomForestClassifier()
scores = cross_val_score(forest_clf, train[features], train['Survived'], cv=5, scoring='accuracy')
print('Scores = {}'.format(scores))
print('Mean = {}'.format(scores.mean()))
print('Std = {}'.format(scores.std()))
# Out:
# Scores = [0.77653631 0.80446927 0.84831461 0.79213483 0.81920904]
# Mean = 0.8081328128684897
# Std = 0.02451511818382855
# /anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
#K-Nearest Neighbours
from sklearn.neighbors import KNeighborsClassifier

knn_clf = KNeighborsClassifier()
scores = cross_val_score(knn_clf, train[features], train['Survived'], cv=5, scoring='accuracy')
print('Scores = {}'.format(scores))
print('Mean = {}'.format(scores.mean()))
print('Std = {}'.format(scores.std()))
# Out:
# Scores = [0.6424581  0.65363128 0.69101124 0.7247191  0.72881356]
# Mean = 0.6881266563751092
# Std = 0.035435291803186234

# %%
#SVM Classifier
from sklearn.svm import LinearSVC

svm_clf = LinearSVC()
scores = cross_val_score(svm_clf, train[features], train['Survived'], cv=5, scoring='accuracy')
print('Scores = {}'.format(scores))
print('Mean = {}'.format(scores.mean()))
print('Std = {}'.format(scores.std()))
# Out:
# Scores = [0.66480447 0.59217877 0.75842697 0.71348315 0.81355932]
# Mean = 0.7084905349233825
# Std = 0.0761510632090793
# /anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %% [markdown]
# # Feature Engineering
#
# Okay, so the best performance we got before any feature engineering was 80%. With the random forest classifier. Lets take a look at the feature_importance of that model to see which features the random forest classifier found the most useful when making the predictions.

# %%
forest_clf.fit(train[features],train['Survived'])
forest_clf.feature_importances_

for feature, weight in zip(features, forest_clf.feature_importances_):
    print("{}: {}".format(feature, weight))
# Out:
# Pclass: 0.07822764636459968
# Sex: 0.3042533894734227
# Age: 0.26540285184318724
# SibSp: 0.04291414481422349
# Parch: 0.03811350671536236
# Fare: 0.24342838145508675
# Embarked_S: 0.014094819785547209
# Embarked_C: 0.008145121558855838
# Embarked_Q: 0.005420137989714656
# /anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %% [markdown]
# ## Bucketize Age and Fare:
#
# So here we can see that both 'Age' and 'Fare' contribute a lot to our model. Let us try to quantize these values by storing them into discrete values.

# %%
train['AgeGroup'] = pd.cut(train['Age'],5, labels=[0,1,2,3,4])
train['FareGroup'] = pd.cut(train['Fare'],4, labels=[0,1,2,3])

# %% [markdown]
# ## Name Feature
#
# One of the features that we neglected in our model was 'Name'. Lets take a closer look at this feature and see if there is any information we can extract out of it.

# %%
train['Name'][0:10].values
# Out:
# array(['Braund, Mr. Owen Harris',
#        'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#        'Heikkinen, Miss. Laina',
#        'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#        'Allen, Mr. William Henry', 'Moran, Mr. James',
#        'McCarthy, Mr. Timothy J', 'Palsson, Master. Gosta Leonard',
#        'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#        'Nasser, Mrs. Nicholas (Adele Achem)'], dtype=object)

# %% [markdown]
# So most of the names in this dataset have a 'Title' associated with it (ie. Mr. Mrs. Miss.) lets extract these titles out and see its correlation with the 'Survived' feature.

# %%
train['Title'] = train['Name'].str.extract('([a-zA-Z]+)\.')
train[['Title','Survived']].groupby('Title').mean()
# Out:
#           Survived
# Title
# Capt      0.000000
# Col       0.500000
# Countess  1.000000
# Don       0.000000
# Dr        0.428571
# Jonkheer  0.000000
# Lady      1.000000
# Major     0.500000
# Master    0.575000
# Miss      0.697802
# Mlle      1.000000
# Mme       1.000000
# Mr        0.156673
# Mrs       0.792000
# Ms        1.000000
# Rev       0.000000
# Sir       1.000000

# %% [markdown]
# Okay, so as we know, females had better survival rate. Therefore people with female titles had better survival rate as well. Whats interesting here is the different male titles like: 'Dr', 'Mr', and, 'Sir' all had different survival rates. These titles could indicate class of the passenger which as we already know correlates with survival rate. Lets try to group these titles into a smaller bucket size.

# %%
titles = {'Capt':       'Officer',
          'Col':        'Officer',
          'Major':      'Officer',
          'Jonkheer':   'Royalty',
          'Don':        'Royalty',
          'Sir' :       'Royalty',
          'Dr':         'Officer',
          'Rev':        'Officer',
          'Countess':   'Royalty',
          'Dona':       'Royalty',
          'Mme':        'Mrs',
          'Mlle':       'Miss',
          'Ms':         'Mrs',
          'Mr' :        'Mr',
          'Mrs' :       'Mrs',
          'Miss' :      'Miss',
          'Master' :    'Master',
          'Lady' :      'Royalty'
                    }

for key,value in titles.items():
    train.loc[train['Title'] == key, 'Title'] = value
    train.loc[train['Title'] == key, 'Title'] = value

train[['Title','Survived']].groupby('Title').mean()
# Out:
#          Survived
# Title
# Master   0.575000
# Miss     0.701087
# Mr       0.156673
# Mrs      0.795276
# Officer  0.277778
# Royalty  0.600000

# %%
#Now, we one hot encode the Titles
encoder = OneHotEncoder()
title_encoded = encoder.fit_transform(train['Title'].values.reshape(-1,1))
train['Title_Master'] = title_encoded.toarray()[:,0]
train['Title_Miss'] = title_encoded.toarray()[:,1]
train['Title_Mr'] = title_encoded.toarray()[:,2]
train['Title_Mrs'] = title_encoded.toarray()[:,3]
train['Title_Officer'] = title_encoded.toarray()[:,4]
train['Title_Royalty'] = title_encoded.toarray()[:,5]

# %% [markdown]
# # Fill in Cabin Missing Data
#
# At first, we just disregarded the 'cabin' attribute because it had so much missing information. Let's take a closer look at this feature and see if we can extract any information from it.

# %%
train['Cabin'].value_counts().sort_index()
# Out:
# A10      1
# A14      1
# A16      1
# A19      1
# A20      1
# A23      1
# A24      1
# A26      1
# A31      1
# A32      1
# A34      1
# A36      1
# A5       1
# A6       1
# A7       1
# B101     1
# B102     1
# B18      2
# B19      1
# B20      2
# B22      2
# B28      2
# B3       1
# B30      1
# B35      2
# B37      1
# B38      1
# B39      1
# B4       1
# B41      1
#         ..
# E12      1
# E121     2
# E17      1
# E24      2
# E25      2
# E31      1
# E33      2
# E34      1
# E36      1
# E38      1
# E40      1
# E44      2
# E46      1
# E49      1
# E50      1
# E58      1
# E63      1
# E67      2
# E68      1
# E77      1
# E8       2
# F E69    1
# F G63    1
# F G73    2
# F2       3
# F33      3
# F38      1
# F4       2
# G6       4
# T        1
# Name: Cabin, Length: 147, dtype: int64

# %% [markdown]
# So it seems that the cabin feature is an alphanumeric code in which the first symbol is represented by a letter from A-T. Let's bucketize these features so that each cabin is just represented by the letter.

# %%
#First we fill in the missing values of Cabin with 'U' for uknown
train['Cabin'].fillna('U',inplace=True)
train['Cabin'] = train['Cabin'].map(lambda x: x[0])
train[['Cabin','Survived']].groupby('Cabin').mean()
# Out:
#        Survived
# Cabin
# A      0.466667
# B      0.744681
# C      0.593220
# D      0.757576
# E      0.750000
# F      0.615385
# G      0.500000
# T      0.000000
# U      0.299854

# %% [markdown]
# Interesting, so we see that people situated in different cabins had different survival rates. I guess this is due to the location of the cabin with respect to the lifeboats. We also notice that most people for whom the cabin information was missing, did not survive.

# %%
#One Hot Encoding the Cabin Feature
encoder = OneHotEncoder()
cabin_encoded = encoder.fit_transform(train['Cabin'].values.reshape(-1,1))

train['Cabin_A'] = cabin_encoded.toarray()[:,0]
train['Cabin_B'] = cabin_encoded.toarray()[:,1]
train['Cabin_C'] = cabin_encoded.toarray()[:,2]
train['Cabin_D'] = cabin_encoded.toarray()[:,3]
train['Cabin_E'] = cabin_encoded.toarray()[:,4]
train['Cabin_F'] = cabin_encoded.toarray()[:,5]
train['Cabin_G'] = cabin_encoded.toarray()[:,6]
train['Cabin_T'] = cabin_encoded.toarray()[:,7]
train['Cabin_U'] = cabin_encoded.toarray()[:,8]

# %%
features = ['Pclass', 'Sex', 'AgeGroup', 'SibSp', 'Parch', 'FareGroup', 'Embarked_S', 'Embarked_C',
            'Embarked_Q', 'Title_Master','Title_Miss','Title_Mr','Title_Mrs','Title_Officer','Title_Royalty',
           'Cabin_A','Cabin_B','Cabin_C','Cabin_D','Cabin_E','Cabin_F','Cabin_G','Cabin_T','Cabin_U']

#Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier

forest_clf = RandomForestClassifier()

scores = cross_val_score(forest_clf, train[features], train['Survived'], cv=3, scoring='accuracy')
print('Scores = {}'.format(scores))
print('Mean = {}'.format(scores.mean()))
print('Std = {}'.format(scores.std()))
# Out:
# Scores = [0.80808081 0.8047138  0.8013468 ]
# Mean = 0.8047138047138048
# Std = 0.002749146737130378
# /anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
forest_clf.fit(train[features],train['Survived'])
forest_clf.feature_importances_

for feature, weight in zip(features, forest_clf.feature_importances_):
    print("{}: {}".format(feature, weight))
# Out:
# Pclass: 0.11594840415329144
# Sex: 0.1416365147808112
# AgeGroup: 0.09214393017896359
# SibSp: 0.09916987459070704
# Parch: 0.0631747360174699
# FareGroup: 0.02092408176716114
# Embarked_S: 0.021958102939277222
# Embarked_C: 0.013571274297767031
# Embarked_Q: 0.011065260035729226
# Title_Master: 0.019133359475002616
# Title_Miss: 0.04833233395714995
# Title_Mr: 0.19205289128712094
# Title_Mrs: 0.011982884160320945
# Title_Officer: 0.010515061570905102
# Title_Royalty: 0.0012043161069295112
# Cabin_A: 0.0045034219526450875
# Cabin_B: 0.010193814979281023
# Cabin_C: 0.007945903280304482
# Cabin_D: 0.0075851453839806725
# Cabin_E: 0.008637970740538752
# Cabin_F: 0.002778478716548215
# Cabin_G: 0.0039348570180206
# Cabin_T: 0.0009722308802714442
# Cabin_U: 0.09063515172980285
# /anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %% [markdown]
# # Tuning the model:
#
# Okay so we found that the RandomForestClassifier seems to be the best model for this application. Lets tune the hyperparameters for this model using GridSearch.

# %%
from sklearn.model_selection import GridSearchCV

param_grid = [
        {
            'n_estimators': [100, 1000], 'criterion': ['gini','entropy'],
            'max_depth': [None], 'min_samples_split':[1,2,4],
            'max_features': ['auto', 'sqrt', 'log2', None]
        }
    ]

forest_clf = RandomForestClassifier()
grid_search = GridSearchCV(forest_clf, param_grid, cv=3, scoring='accuracy', verbose=0)
# Out:
# Fitting 3 folds for each of 768 candidates, totalling 2304 fits
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_split=1.0, n_estimators=10
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_split=1.0, n_estimators=10, score=0.6161616161616161, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_split=1.0, n_estimators=10
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_split=1.0, n_estimators=10, score=0.6161616161616161, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_split=1.0, n_estimators=10
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_split=1.0, n_estimators=10, score=0.6161616161616161, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_split=1.0, n_estimators=100
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_split=1.0, n_estimators=100, score=0.6161616161616161, total=   0.1s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_split=1.0, n_estimators=100
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.2s remaining:    0.0s
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_split=1.0, n_estimators=100, score=0.6161616161616161, total=   0.1s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_split=1.0, n_estimators=100
# [CV]  criterion=gini, max_depth=None, max_features=auto, min_samples_split=1.0, n_estimators=100, score=0.6161616161616161, total=   0.1s
# [CV] criterion=gini, max_depth=None, max_features=auto, min_samples_split

# [CV] criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=8, n_estimators=100, score=0.8249158249158249, total=   0.1s
# [CV] criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=8, n_estimators=1000
# [CV]  criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=8, n_estimators=1000, score=0.7946127946127947, total=   0.9s
# [CV] criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=8, n_estimators=1000
# [CV]  criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=8, n_estimators=1000, score=0.8383838383838383, total=   0.9s
# [CV] criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=8, n_estimators=1000
# [CV]  criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=8, n_estimators=1000, score=0.8282828282828283, total=   0.9s
# [CV] criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=8, n_estimators=10000
# [CV]  criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=8, n_estimators=10000, score=0.797979797979798, total=  10.5s
# [CV] criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=8, n_estimators=10000
# [CV]  criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=8, n_estimators=10000, score=0.8383838383838383, total=   8.5s
# [CV] criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=8, n_estimators=10000
# [CV]  criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=8, n_estimators=10000, score=0.8282828282828283, total=   9.2s
# [CV] criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=16, n_estimators=10
# [CV]  criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=16, n_estimators=10, score=0.7878787878787878, total=   0.0s
# [CV] criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=16, n_estimators=10
# [CV]  criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=16, n_estimators=10, score=0.835016835016835, total=   0.0s
# [CV] criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=16, n_estimators=10
# [CV]  criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=16, n_estimators=10, score=0.8148148148148148, total=   0.0s
# [CV] criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=16, n_estimators=100
# [CV]  criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=16, n_estimators=100, score=0.797979797979798, total=   0.1s
# [CV] criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=16, n_estimators=100
# [CV]  criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=16, n_estimators=100, score=0.8417508417508418, total=   0.1s
# [CV] criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=16, n_estimators=100
# [CV]  criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=16, n_estimators=100, score=0.8215488215488216, total=   0.1s
# [CV] criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=16, n_estimators=1000
# [CV]  criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=16, n_estimators=1000, score=0.7946127946127947, total=   0.9s
# [CV] criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=16, n_estimators=1000
# [CV]  criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=16, n_estimators=1000, score=0.835016835016835, total=   0.8s
# [CV] criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=16, n_estimators=1000
# [CV]  criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=16, n_estimators=1000, score=0.8215488215488216, total=   0.8s
# [CV] criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=16, n_estimators=10000
# [CV]  criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=16, n_estimators=10000, score=0.7946127946127947, total=   8.7s
# [CV] criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=16, n_estimators=10000
# [CV]  criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=16, n_estimators=10000, score=0.8316498316498316, total=   8.2s
# [CV] criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=16, n_estimators=10000
# [CV]  criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=16, n_estimators=10000, score=0.8215488215488216, total=   8.2s
# [CV] criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=32, n_estimators=10
# [CV]  criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=32, n_estimators=10, score=0.7441077441077442, total=   0.0s
# [CV] criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=32, n_estimators=10
# [CV]  criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=32, n_estimators=10, score=0.8249158249158249, total=   0.0s
# [CV] criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=32, n_estimators=10
# [CV]  criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=32, n_estimators=10, score=0.8114478114478114, total=   0.0s
# [CV] criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=32, n_estimators=100
# [CV]  criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=32, n_estimators=100, score=0.7946127946127947, total=   0.1s
# [CV] criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=32, n_estimators=100
# [CV]  criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=32, n_estimators=100, score=0.8316498316498316, total=   0.1s
# [CV] criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=32, n_estimators=100
# [CV]  criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=32, n_estimators=100, score=0.8148148148148148, total=   0.1s
# [CV] criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=32, n_estimators=1000
# [CV]  criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=32, n_estimators=1000, score=0.7878787878787878, total=   1.4s
# [CV] criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=32, n_estimators=1000
# [CV]  criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=32, n_estimators=1000, score=0.8383838383838383, total=   0.8s
# [CV] criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=32, n_estimators=1000
# [CV]  criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=32, n_estimators=1000, score=0.8114478114478114, total=   0.8s
# [CV] criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=32, n_estimators=10000
# [CV]  criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=32, n_estimators=10000, score=0.797979797979798, total=   8.4s
# [CV] criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=32, n_estimators=10000
# [CV]  criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=32, n_estimators=10000, score=0.8383838383838383, total=   9.2s
# [CV] criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=32, n_estimators=10000
# [CV]  criterion=entropy, max_depth=None, max_features=sqrt, min_samples_split=32, n_estimators=10000, score=0.8181818181818182, total=   7.9s
# [CV] criterion=entropy, max_depth=None, max_features=log2, min_samples_split=1.0, n_estimators=10
# [CV]  criterion=entropy, max_depth=None, max_features=log2, min_samples_split=1.0, n_estimators=10, score=0.6161616161616161, total=   0.0s
# [CV] criterion=entropy, max_depth=None, max_features=log2, min_samples_split=1.0, n_estimators=10
# [CV]  criterion=entropy, max_depth=None, max_features=log2, min_samples_split=1.0, n_estimators=10, score=0.6161616161616161, total=   0.0s
# [CV] criterion=entropy, max_depth=None, max_features=log2, min_samples_split=1.0, n_estimators=10
# [CV]  criterion=entropy, max_depth=None, max_features=log2, min_samples_split=1.0, n_estimators=10, score=0.6161616161616161, total=   0.0s
# [CV] criterion=entropy, max_depth=None, max_features=log2, min_samples_split=1.0, n_estimators=100
# [CV]  criterion=entropy, max_depth=None, max_features=log2, min_samples_split=1.0, n_estimators=100, score=0.6161616161616161, total=   0.1s
# [CV] criterion=entropy, max_depth=None, max_features=log2, min_samples_split=1.0, n_estimators=100
# [CV]  criterion=entropy, max_depth=None, max_features=log2, min_samples_split=1.0, n_estimators=100, score=0.6161616161616161, total=   0.1s
# [CV] criterion=entropy, max_depth=None, max_features=log2, min_samples_split=1.0, n_estimators=100
# [CV]  criterion=entropy, max_depth=None, max_features=log2, min_samples_split=1.0, n_estimators=100, score=0.6161616161616161, total=   0.1s
# [CV] criterion=entropy, max_depth=None, max_features=log2, min_samples_split=1.0, n_estimators=1000
# [CV]  criterion=entropy, max_depth=None, max_features=log2, min_samples_split=1.0, n_estimators=1000, score=0.6161616161616161, total=   0.7s
# [CV] criterion=entropy, max_depth=None, max_features=log2, min_samples_split=1.0, n_estimators=1000
# [CV]  criterion=entropy, max_depth=None, max_features=log2, min_samples_split=1.0, n_estimators=1000, score=0.6161616161616161, total=   0.8s
# [CV] criterion=entropy, max_depth=None, max_features=log2, min_samples_split=1.0, n_estimators=1000
# [CV]  criterion=entropy, max_depth=None, max_features=log2, min_samples_split=1.0, n_estimators=1000, score=0.6161616161616161, total=   0.7s
# [CV] criterion=entropy, max_depth=None, max_features=log2, min_samples_split=1.0, n_estimators=10000
# [CV]  criterion=entropy, max_depth=None, max_features=log2, min_samples_split=1.0, n_estimators=10000, score=0.6161616161616161, total=   6.9s
# [CV] criterion=entropy, max_depth=None, max_features=log2, min_samples_split=1.0, n_estimators=10000
